# %%
import os                                                                       
from multiprocessing import Pool                                                
                                                                                
                                                                                
processes = ('twitch_chat_scraper.py', 'twitch_chat_metadata_scraper.py') 
                                                  
                                                                                
def run_process(process):                                                             
    os.system('python {}'.format(process))                                       
                                                                                
                                                                                
pool = Pool(processes=2)                                                        
pool.map(run_process, processes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-69de70e05d52> in <module>
#      11
#      12 pool = Pool(processes=2)
# ---> 13 pool.map(run_process, processes)
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     288         in a list that is returned.
#     289         '''
# --> 290         return self._map_async(func, iterable, mapstar, chunksize).get()
#     291
#     292     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     675
#     676     def get(self, timeout=None):
# --> 677         self.wait(timeout)
#     678         if not self.ready():
#     679             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     672
#     673     def wait(self, timeout=None):
# --> 674         self._event.wait(timeout)
#     675
#     676     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-6:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
import sys
with open(sys.argv[1], 'r') as f:
    contents = f.read()
print (contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2bfe8c20078c> in <module>
#       1 import sys
# ----> 2 with open(sys.argv[1], 'r') as f:
#       3     contents = f.read()
#       4 print (contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: '-f'

# %%
import os                                                                       
from multiprocessing import Pool    

                                                                                
# processes = ('twitch_chat_scraper.py', 'twitch_chat_metadata_scraper.py')     
                                  


    
def run_process(process):                                                             
    os.system('python {}'.format(process))                                       
                                                                                
                                        
if __name__ == "__main__":
              
    lst = ['singsing', 'edisonparklive']
    processes = t.twitch_chat_metadata_scraper(lst[0])   

    pool = Pool(processes=1)                                                        
    pool.map(run_process, processes)

# %%
import os
from twitch import TwitchHelix
client = TwitchHelix(client_id=os.environ.get('TWITCH_CLIENT_KEY'))

get_streams = client.get_streams(page_size=100)[1:]

top_50_channel_list = []

for stream in get_streams:
    top_50_channel_list.append(stream['user_name'])
    
my_list = top_50_channel_list[40:]
my_list = my_list + ['bmkibler']

# %%
import os                                                                       
from multiprocessing import Pool                                                                       
                                                                                  

def twitch_chat_metadata_scraper(channel_name):
        print('getting metadata for channel: ' + channel_name + '\n')
        log_path = '../chat_log_data/'
        log_file_name = log_path + channel_name + '_stream_metadata.txt'

        #Twitch API calls
        from itertools import islice
        from twitch import TwitchHelix
        import os

        client = TwitchHelix(client_id=os.environ.get('TWITCH_CLIENT_KEY'))

        f = open(log_file_name,"a+")
        f.close()

        #writes to time and data to file
        import time
        starttime=time.time()
        import datetime

        while True:
            #gets current channel metadata
            
            streams_iterator = client.get_streams(user_logins=channel_name)
            stream_data = streams_iterator.next()

            #gets current datetime
            now = str(datetime.datetime.now().isoformat())

            #prints current time output
        #     print ("tick- ",now)

            #writes time and channel metadata to file
            data = str(now+str(stream_data)+"\n")
            f = open(log_file_name,"a+")
            f.write(data)
            print(data)
            f.close()

            time.sleep(60.0 - ((time.time() - starttime) % 60.0))

def run_process(process):                                                             
    os.system('python {}'.format(process)) 

if __name__ == "__main__":    
    processes = my_list
    pool = Pool(processes=len(my_list))                                                        
    pool.map(twitch_chat_metadata_scraper, processes)
# Out:
# getting metadata for channel: Philza
# getting metadata for channel: witwix
# getting metadata for channel: JustCooman
# getting metadata for channel: RduLIVE
# getting metadata for channel: EWROON
# getting metadata for channel: SolaryFortnite
# getting metadata for channel: KYR_SP33DY
# getting metadata for channel: Tumblurr
# getting metadata for channel: FENGRUSH
# getting metadata for channel: KabajiOW
# getting metadata for channel: Northernlion
# getting metadata for channel: guit88man
# getting metadata for channel: MarcaoRX
#
# getting metadata for channel: Savjz
#
#
# getting metadata for channel: IamCristinini
# getting metadata for channel: LazarBeamTwitch
#
# getting metadata for channel: AvoidingThePuddle
#
#
#
# getting metadata for channel: Grimnax
# getting metadata for channel: masondota2
#
# getting metadata for channel: Solary
# getting metadata for channel: cyr
# getting metadata for channel: SwaggerSouls
#
# getting metadata for channel: TFBlade
#
#
#
#
#
# getting metadata for channel: JLTomy
# getting metadata for channel: follentass
# getting metadata for channel: MrSavage
# getting metadata for channel: FollowGrubby
#
#
#
# getting metadata for channel: AlexRamiGaming
# getting metadata for channel: imaqtpie
#
#
# getting metadata for channel: kutcherlol
# getting metadata for channel: h3x_TV
#
#
# getting metadata for channel: UMGEvents
# getting metadata for channel: Locklear
# getting metadata for channel: 72hrs
# getting metadata for channel: PokerStaples
#
#
#
#
# getting metadata for channel: gaules
# getting metadata for channel: Giantwaffle
#
# getting metadata for channel: Jenna
#
# getting metadata for channel: SolaryHS
#
# getting metadata for channel: mendokusaii
#
#
#
# getting metadata for channel: quackityhq
#
# getting metadata for channel: ZEON
# getting metadata for channel: WPMEzony
#
#
#
# getting metadata for channel: Skyyart
#
# getting metadata for channel: Attrix
# getting metadata for channel: MrRemxTV
#
# getting metadata for channel: A_Seagull
# getting metadata for channel: cdewx
# getting metadata for channel: PAGO3
#
#
#
# getting metadata for channel: IzakOOO
# getting metadata for channel: ziGueira
#
#
#
#
# getting metadata for channel: JoltzDude139
# getting metadata for channel: PaymoneyWubby
#
#
# getting metadata for channel: benjyfishy
#
# getting metadata for channel: CurtisRyan_
#
# getting metadata for channel: TrumpSC
#
# getting metadata for channel: canceldota
# getting metadata for channel: jschlatt
#
#
# getting metadata for channel: AdzTV
# getting metadata for channel: bmkibler
#
#
#
#
#
#
#
#
#
# 2019-07-01T15:34:44.289680{'id': '34742126896', 'user_id': '25604128', 'user_name': 'guit88man', 'game_id': '115977', 'community_ids': ['d808cf0b-88c3-4ef2-acd0-bae82f17e9c3'], 'type': 'live', 'title': 'Ведьмак 3 - день 2', 'viewer_count': 4025, 'started_at': datetime.datetime(2019, 7, 1, 18, 11, 2), 'language': 'ru', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_guit88man-{width}x{height}.jpg', 'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327']}
# 2019-07-01T15:34:44.289562{'id': '34742655344', 'user_id': '63667409', 'user_name': 'JustCooman', 'game_id': '29595', 'community_ids': [], 'type': 'live', 'title': '123qwe', 'viewer_count': 4558, 'started_at': datetime.datetime(2019, 7, 1, 18, 55, 13), 'language': 'ru', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_justcooman-{width}x{height}.jpg', 'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327']}
#
# 2019-07-01T15:34:44.291249{'id': '34737937840', 'user_id': '198506129', 'user_name': 'SolaryFortnite', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': "GTA LIFE | LE RETOUR D'ETHANOU", 'viewer_count': 4379, 'started_at': datetime.datetime(2019, 7, 1, 9, 23, 46), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solaryfortnite-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
#
#
# 2019-07-01T15:34:44.333528{'id': '34741969088', 'user_id': '3389768', 'user_name': 'Philza', 'game_id': '27471', 'community_ids': ['0b9d06f9-fe5f-4f69-a4c3-2a9ee5604fb7'], 'type': 'live', 'title': '#MinecraftMonday $10,000 tourny w/ JeromeASF we PG today lmao', 'viewer_count': 4569, 'started_at': datetime.datetime(2019, 7, 1, 17, 59, 15), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_philza-{width}x{height}.jpg', 'tag_ids': ['ba2c968b-867a-49ce-aebc-3d978a204f4a', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:34:44.334816{'id': '34741951744', 'user_id': '43131877', 'user_name': 'Savjz', 'game_id': '512693', 'community_ids': [], 'type': 'live', 'title': '[Big Boss] Savjz fun builds', 'viewer_count': 3957, 'started_at': datetime.datetime(2019, 7, 1, 17, 57, 57), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_savjz-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:34:44.340594{'id': '34741325712', 'user_id': '82197170', 'user_name': 'EWROON', 'game_id': '32982', 'community_ids': ['5181e78f-2280-42a6-873d-758e25a7c313'], 'type': 'live', 'title': '<EWRON> UDAWANE ŻYCIE! -> KOD EWRON W SKLEPIE FORTNITE! <- !ig !fb', 'viewer_count': 4293, 'started_at': datetime.datetime(2019, 7, 1, 17, 1, 42), 'language': 'pl', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_ewroon-{width}x{height}.jpg', 'tag_ids': ['f9d04efa-6e25-49bf-bf0a-da3e2addaf1b']}
#
# 2019-07-01T15:34:44.350382{'id': '34743486944', 'user_id': '11001241', 'user_name': 'KYR_SP33DY', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': '#MinecraftMonday Hunger Games starts at 1PM PDT/4pm EDT', 'viewer_count': 4295, 'started_at': datetime.datetime(2019, 7, 1, 20, 2, 53), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kyr_sp33dy-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.350196{'id': '34744761920', 'user_id': '14371185', 'user_name': 'Northernlion', 'game_id': '498380', 'community_ids': [], 'type': 'live', 'title': 'The Northernlion Live Super Show! (Rock of Ages 2 / Golf It / Hand Simulator)', 'viewer_count': 4138, 'started_at': datetime.datetime(2019, 7, 1, 22, 0, 35), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_northernlion-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:34:44.350283{'id': '34743531232', 'user_id': '123922797', 'user_name': 'IamCristinini', 'game_id': '32982', 'community_ids': ['14778f2b-de66-48d7-ae0b-8187250de029', '831ccb45-e159-4873-a61b-74693bdc5756', 'ad14d4fc-1a7c-413f-aa32-4906ef3669ae'], 'type': 'live', 'title': '🔴 [DespistaosRp] 👮\u200d♀️ POLICIA - Cadete Irina Wallace - LSPD [+18] | Follow @IamCristinini', 'viewer_count': 3955, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 34), 'language': 'es', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_iamcristinini-{width}x{height}.jpg', 'tag_ids': ['d4bb9c58-2141-4881-bcdc-3fe0505457d1']}
# 2019-07-01T15:34:44.350425{'id': '34739184896', 'user_id': '59965916', 'user_name': 'RduLIVE', 'game_id': '138585', 'community_ids': ['136d5c6a-a7ed-4b6d-aedb-1deb08793157'], 'type': 'live', 'title': 'Rdu - PATCH LIVE | Pilfer Is OP', 'viewer_count': 4403, 'started_at': datetime.datetime(2019, 7, 1, 12, 59, 9), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_rdulive-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
#
# 2019-07-01T15:34:44.357083{'id': '34743818352', 'user_id': '11558942', 'user_name': 'witwix', 'game_id': '511399', 'community_ids': [], 'type': 'live', 'title': 'Supa Mario Maker 2', 'viewer_count': 4641, 'started_at': datetime.datetime(2019, 7, 1, 20, 31, 38), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_witwix-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.357093{'id': '34742523344', 'user_id': '94269217', 'user_name': 'FENGRUSH', 'game_id': '65654', 'community_ids': ['3cefa9a9-f428-45be-a993-2d8ce3f22869', '42d21364-b9fc-4804-aa51-5cc8d9740c82', 'cd48a452-3437-48ad-af47-0c2ee51c8b78'], 'type': 'live', 'title': 'EU Server is Down - !giveaway !beginner', 'viewer_count': 4177, 'started_at': datetime.datetime(2019, 7, 1, 18, 44, 7), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_fengrush-{width}x{height}.jpg', 'tag_ids': ['77223888-8535-4614-974b-b1b2673456eb', '64d9afa6-139a-48d5-ab4e-51d0a92b22de', '5464696d-e140-4625-94fd-1d0001e4b1ee', 'd4461e94-570b-4973-b6a1-3afe026c12ca', '1eea2343-ca8e-4606-ab21-5c64e129f6db', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.368555{'id': '34744066928', 'user_id': '129112562', 'user_name': 'AlexRamiGaming', 'game_id': '33214', 'community_ids': [], 'type': 'live', 'title': 'Custom Games with Viewers!', 'viewer_count': 3080, 'started_at': datetime.datetime(2019, 7, 1, 20, 54, 26), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_alexramigaming-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', 'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e', 'ac763b17-7bea-4632-9eb4-d106689ff409', '8486f56b-8677-44f7-8004-000295391524']}
# 2019-07-01T15:34:44.368668{'id': '34741209840', 'user_id': '114476906', 'user_name': 'KabajiOW', 'game_id': '488552', 'community_ids': ['8ea1e94f-4015-4f38-bd7e-745d8f42539a'], 'type': 'live', 'title': 'HIGH RANKED GAMES BOIS', 'viewer_count': 4021, 'started_at': datetime.datetime(2019, 7, 1, 16, 51, 18), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kabajiow-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '99e3f06a-a2b9-4963-bd2f-45283d644bc6']}
# 2019-07-01T15:34:44.368583{'id': '34743563632', 'user_id': '37522866', 'user_name': 'cyr', 'game_id': '32982', 'community_ids': ['ab18bbee-75ed-409d-aba9-8d4e3e2e541a', 'fd0eab99-832a-4d7e-8cc0-04d73deb2e54', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': "Uchiha Jones , he's not cute, he's tough", 'viewer_count': 3624, 'started_at': datetime.datetime(2019, 7, 1, 20, 9, 23), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cyr-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.368871{'id': '34744541024', 'user_id': '90888563', 'user_name': 'h3x_TV', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': 'Vahşit | !yemeksepeti', 'viewer_count': 3042, 'started_at': datetime.datetime(2019, 7, 1, 21, 38, 54), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_h3x_tv-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
# 2019-07-01T15:34:44.369177{'id': '34743616832', 'user_id': '101725379', 'user_name': 'LazarBeamTwitch', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': 'playing minecraft with pewdiepie and james charles', 'viewer_count': 3947, 'started_at': datetime.datetime(2019, 7, 1, 20, 13, 58), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_lazarbeamtwitch-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
#
#
# 2019-07-01T15:34:44.372422{'id': '34742796240', 'user_id': '155601320', 'user_name': 'JLTomy', 'game_id': '32982', 'community_ids': ['4481e651-74ba-47f4-8374-9f94ec793d2a', '9133c470-6db4-4e16-a5d0-690e8a005bea'], 'type': 'live', 'title': 'JL TOMA - Yanis Abdouben de retour sur FlashLand ! (twitter : @PrismTomy) !video !rt !hrp', 'viewer_count': 3521, 'started_at': datetime.datetime(2019, 7, 1, 19, 5, 36), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_jltomy-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:34:44.372505{'id': '34743187888', 'user_id': '16146075', 'user_name': 'Grimnax', 'game_id': '32982', 'community_ids': ['fd0eab99-832a-4d7e-8cc0-04d73deb2e54'], 'type': 'live', 'title': 'tek kişilik dev Gang | voRP | !yemeksepeti !prime !funny !güncelleme | insta: grimnax', 'viewer_count': 3896, 'started_at': datetime.datetime(2019, 7, 1, 19, 38, 4), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_grimnax-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
# 2019-07-01T15:34:44.373281{'id': '34742098928', 'user_id': '24991333', 'user_name': 'imaqtpie', 'game_id': '29307', 'community_ids': [], 'type': 'live', 'title': 'spin good', 'viewer_count': 3136, 'started_at': datetime.datetime(2019, 7, 1, 18, 8, 47), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_imaqtpie-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.374157{'id': '34742536080', 'user_id': '20992865', 'user_name': 'FollowGrubby', 'game_id': '12924', 'community_ids': ['848d95be-90b3-44a5-b143-6e373754c382', 'eb998ad4-8f95-4664-8ad4-08ca956a2e32', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': 'Mundead Monday - playing BEST race - !prime !buildorders !discord', 'viewer_count': 3160, 'started_at': datetime.datetime(2019, 7, 1, 18, 45, 12), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_followgrubby-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
#
# 2019-07-01T15:34:44.377982{'id': '34743052320', 'user_id': '40754777', 'user_name': 'masondota2', 'game_id': '29595', 'community_ids': [], 'type': 'live', 'title': ' RANK 1', 'viewer_count': 3961, 'started_at': datetime.datetime(2019, 7, 1, 19, 26, 44), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_masondota2-{width}x{height}.jpg', 'tag_ids': ['3dc8f084-d886-4264-b20f-8bd5f90562b5', '60b8f13e-7022-481a-afff-07de3db129cc', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.378092{'id': '34743894176', 'user_id': '193054811', 'user_name': 'MarcaoRX', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': '18+ [UP-RP] MARCÃO DEUS? FÉ  --> !ofertas  !sociais', 'viewer_count': 4091, 'started_at': datetime.datetime(2019, 7, 1, 20, 38, 23), 'language': 'pt', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_marcaorx-{width}x{height}.jpg', 'tag_ids': ['39ee8140-901a-4762-bfca-8260dea1310f']}
#
#
# 2019-07-01T15:34:44.384465{'id': '34743337552', 'user_id': '112837021', 'user_name': 'UMGEvents', 'game_id': '27471', 'community_ids': ['4203fe60-1a97-441a-9e5b-9952a31e22b0', '558ffafb-6f75-44ff-8cb7-a4f045d2399f', 'e460229e-2100-4c42-894c-d758651f06c6'], 'type': 'live', 'title': 'Minecraft Monday Week 2', 'viewer_count': 2762, 'started_at': datetime.datetime(2019, 7, 1, 19, 50, 52), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_umgevents-{width}x{height}.jpg', 'tag_ids': ['b13ce7d5-d513-49ff-a957-76f193df42aa', '1eba3cfe-51cc-460a-8259-bc8bb987f904', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:34:44.386741{'id': '34740706752', 'user_id': '22552479', 'user_name': 'Giantwaffle', 'game_id': '495764', 'community_ids': ['23653182-871f-44d5-990c-68fc600abcf0', '5181e78f-2280-42a6-873d-758e25a7c313', 'fd0eab99-832a-4d7e-8cc0-04d73deb2e54'], 'type': 'live', 'title': 'Last Stream Before Vacation | !charm for R6 Charm', 'viewer_count': 2600, 'started_at': datetime.datetime(2019, 7, 1, 16, 0, 57), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_giantwaffle-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.387071{'id': '34744467152', 'user_id': '59308271', 'user_name': 'TFBlade', 'game_id': '21779', 'community_ids': [], 'type': 'live', 'title': 'NEW EMOTES SOON', 'viewer_count': 3603, 'started_at': datetime.datetime(2019, 7, 1, 21, 31, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tfblade-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:34:44.386835{'id': '34740584352', 'user_id': '72980942', 'user_name': 'PokerStaples', 'game_id': '488190', 'community_ids': ['0b9d06f9-fe5f-4f69-a4c3-2a9ee5604fb7', '848d95be-90b3-44a5-b143-6e373754c382', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': 'Final Table $530 and 1/18 $320 Gladiator!', 'viewer_count': 2693, 'started_at': datetime.datetime(2019, 7, 1, 15, 49, 2), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_pokerstaples-{width}x{height}.jpg', 'tag_ids': ['1eba3cfe-51cc-460a-8259-bc8bb987f904', 'cea7bc0c-75a5-4446-8743-6db031b71550', 'b13ce7d5-d513-49ff-a957-76f193df42aa', 'ac763b17-7bea-4632-9eb4-d106689ff409', 'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e', '6ea6bca4-4712-4ab9-a906-e3336a9d8039', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:34:44.392232{'id': '34742045184', 'user_id': '137347549', 'user_name': 'Locklear', 'game_id': '494925', 'community_ids': ['7f4e3996-78e8-46f6-bed0-586075cdd8ba'], 'type': 'live', 'title': 'UN HOMME ET UNE FEMME SUR UN RADEAU !Extension', 'viewer_count': 2913, 'started_at': datetime.datetime(2019, 7, 1, 18, 4, 34), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_locklear-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
#
# 2019-07-01T15:34:44.400906{'id': '34742666576', 'user_id': '77827128', 'user_name': 'Tumblurr', 'game_id': '510579', 'community_ids': [], 'type': 'live', 'title': 'LIVE NOIOSA NON ENTRATE | !sub !prime !donazioni', 'viewer_count': 4216, 'started_at': datetime.datetime(2019, 7, 1, 18, 56, 1), 'language': 'it', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tumblurr-{width}x{height}.jpg', 'tag_ids': ['5b9935eb-1e9a-4217-98ad-62bda5cff0d1', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:34:44.400966{'id': '34743525712', 'user_id': '84432477', 'user_name': 'SwaggerSouls', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': "Minecraft Mondays but I'm geeking on GamerSupps", 'viewer_count': 3599, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 5), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_swaggersouls-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
# 2019-07-01T15:34:44.416399{'id': '34740854112', 'user_id': '174955366', 'user_name': 'Solary', 'game_id': '513143', 'community_ids': [], 'type': 'live', 'title': 'Narkuss hard train twitch rival TOURNOI VIEUWEUR', 'viewer_count': 3661, 'started_at': datetime.datetime(2019, 7, 1, 16, 15, 42), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solary-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
#
# 2019-07-01T15:34:44.423285{'id': '34743314272', 'user_id': '23528098', 'user_name': 'AvoidingThePuddle', 'game_id': '509482', 'community_ids': [], 'type': 'live', 'title': 'Judge Eyes - Buy a shirt will ya? teespring.com/stores/ATP', 'viewer_count': 3900, 'started_at': datetime.datetime(2019, 7, 1, 19, 48, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_avoidingthepuddle-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:34:44.425039{'id': '34741613632', 'user_id': '14836307', 'user_name': 'TrumpSC', 'game_id': '138585', 'community_ids': [], 'type': 'live', 'title': 'Token Druid! ...Heist!', 'viewer_count': 2221, 'started_at': datetime.datetime(2019, 7, 1, 17, 28, 2), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_trumpsc-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '7f613168-c2fb-48f7-948b-a51aa8fd53d0']}
#
# 2019-07-01T15:34:44.445574{'id': '34741263712', 'user_id': '101286926', 'user_name': 'WPMEzony', 'game_id': '27471', 'community_ids': ['630b0566-cee6-42e4-84ad-a18532d7f56b', 'c8f59921-b10b-49ab-99ac-0a8dc49df36d'], 'type': 'live', 'title': 'GALAKTYCZNY MOD O 20 !mody2 !jak 🍯KOD:HONEY🍯😡18+😡', 'viewer_count': 2497, 'started_at': datetime.datetime(2019, 7, 1, 16, 56, 31), 'language': 'pl', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_wpmezony-{width}x{height}.jpg', 'tag_ids': ['f1e3759c-35b3-4858-a50f-8f9cafc2660f', '2b2a4874-8a3c-4995-b9e2-2a0bce1eb536', 'e90b5f6e-4c6e-4003-885b-4d0d5adeb580', '8282259b-a997-4c63-b908-24027f64ac9a', 'fd8f5e68-42d3-4544-a273-5fc92dabc568', 'f9d04efa-6e25-49bf-bf0a-da3e2addaf1b']}
# 2019-07-01T15:34:44.445661{'id': '34742723040', 'user_id': '32171655', 'user_name': 'ziGueira', 'game_id': '460630', 'community_ids': [], 'type': 'live', 'title': 'Rankeando e Tryhardando  !amazon !sub !sorteio !donate ', 'viewer_count': 2315, 'started_at': datetime.datetime(2019, 7, 1, 19, 0, 15), 'language': 'pt', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_zigueira-{width}x{height}.jpg', 'tag_ids': ['39ee8140-901a-4762-bfca-8260dea1310f', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:34:44.446416{'id': '34742791472', 'user_id': '53571235', 'user_name': 'MrRemxTV', 'game_id': '32982', 'community_ids': ['302fa16e-9999-4259-86ec-ba5817725a9a', 'a2095c74-abc0-41cf-af39-1ca3c5ee88e1'], 'type': 'live', 'title': 'Flashland: Jason recherche TheSilentRipper', 'viewer_count': 2426, 'started_at': datetime.datetime(2019, 7, 1, 19, 5, 14), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_mrremxtv-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
#
#
#
# 2019-07-01T15:35:44.202813{'id': '34737937840', 'user_id': '198506129', 'user_name': 'SolaryFortnite', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': "GTA LIFE | LE RETOUR D'ETHANOU", 'viewer_count': 4317, 'started_at': datetime.datetime(2019, 7, 1, 9, 23, 46), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solaryfortnite-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:35:44.202901{'id': '34742655344', 'user_id': '63667409', 'user_name': 'JustCooman', 'game_id': '29595', 'community_ids': [], 'type': 'live', 'title': '123qwe', 'viewer_count': 4454, 'started_at': datetime.datetime(2019, 7, 1, 18, 55, 13), 'language': 'ru', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_justcooman-{width}x{height}.jpg', 'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327']}
# 2019-07-01T15:35:44.202943{'id': '34739184896', 'user_id': '59965916', 'user_name': 'RduLIVE', 'game_id': '138585', 'community_ids': ['136d5c6a-a7ed-4b6d-aedb-1deb08793157'], 'type': 'live', 'title': 'Rdu - PATCH LIVE | Pilfer Is OP', 'viewer_count': 4396, 'started_at': datetime.datetime(2019, 7, 1, 12, 59, 9), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_rdulive-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
# 2019-07-01T15:35:44.206967{'id': '34743894176', 'user_id': '193054811', 'user_name': 'MarcaoRX', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': '18+ [UP-RP] MARCÃO DEUS? FÉ  --> !ofertas  !sociais', 'viewer_count': 4141, 'started_at': datetime.datetime(2019, 7, 1, 20, 38, 23), 'language': 'pt', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_marcaorx-{width}x{height}.jpg', 'tag_ids': ['39ee8140-901a-4762-bfca-8260dea1310f']}
#
# 2019-07-01T15:35:44.210122{'id': '34743486944', 'user_id': '11001241', 'user_name': 'KYR_SP33DY', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': '#MinecraftMonday Hunger Games starts at 1PM PDT/4pm EDT', 'viewer_count': 4300, 'started_at': datetime.datetime(2019, 7, 1, 20, 2, 53), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kyr_sp33dy-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:35:44.212558{'id': '34742523344', 'user_id': '94269217', 'user_name': 'FENGRUSH', 'game_id': '65654', 'community_ids': ['3cefa9a9-f428-45be-a993-2d8ce3f22869', '42d21364-b9fc-4804-aa51-5cc8d9740c82', 'cd48a452-3437-48ad-af47-0c2ee51c8b78'], 'type': 'live', 'title': 'EU Server is Down - !giveaway !beginner', 'viewer_count': 4177, 'started_at': datetime.datetime(2019, 7, 1, 18, 44, 7), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_fengrush-{width}x{height}.jpg', 'tag_ids': ['77223888-8535-4614-974b-b1b2673456eb', '64d9afa6-139a-48d5-ab4e-51d0a92b22de', '5464696d-e140-4625-94fd-1d0001e4b1ee', 'd4461e94-570b-4973-b6a1-3afe026c12ca', '1eea2343-ca8e-4606-ab21-5c64e129f6db', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.212841{'id': '34742126896', 'user_id': '25604128', 'user_name': 'guit88man', 'game_id': '115977', 'community_ids': ['d808cf0b-88c3-4ef2-acd0-bae82f17e9c3'], 'type': 'live', 'title': 'Ведьмак 3 - день 2', 'viewer_count': 4029, 'started_at': datetime.datetime(2019, 7, 1, 18, 11, 2), 'language': 'ru', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_guit88man-{width}x{height}.jpg', 'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327']}
# 2019-07-01T15:35:44.219021{'id': '34743531232', 'user_id': '123922797', 'user_name': 'IamCristinini', 'game_id': '32982', 'community_ids': ['14778f2b-de66-48d7-ae0b-8187250de029', '831ccb45-e159-4873-a61b-74693bdc5756', 'ad14d4fc-1a7c-413f-aa32-4906ef3669ae'], 'type': 'live', 'title': '🔴 [DespistaosRp] 👮\u200d♀️ POLICIA - Cadete Irina Wallace - LSPD [+18] | Follow @IamCristinini', 'viewer_count': 3984, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 34), 'language': 'es', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_iamcristinini-{width}x{height}.jpg', 'tag_ids': ['d4bb9c58-2141-4881-bcdc-3fe0505457d1']}
# 2019-07-01T15:35:44.220119{'id': '34742666576', 'user_id': '77827128', 'user_name': 'Tumblurr', 'game_id': '510579', 'community_ids': [], 'type': 'live', 'title': 'LIVE NOIOSA NON ENTRATE | !sub !prime !donazioni', 'viewer_count': 4278, 'started_at': datetime.datetime(2019, 7, 1, 18, 56, 1), 'language': 'it', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tumblurr-{width}x{height}.jpg', 'tag_ids': ['5b9935eb-1e9a-4217-98ad-62bda5cff0d1', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:35:44.219779{'id': '34741969088', 'user_id': '3389768', 'user_name': 'Philza', 'game_id': '27471', 'community_ids': ['0b9d06f9-fe5f-4f69-a4c3-2a9ee5604fb7'], 'type': 'live', 'title': '#MinecraftMonday $10,000 tourny w/ JeromeASF we PG today lmao', 'viewer_count': 4549, 'started_at': datetime.datetime(2019, 7, 1, 17, 59, 15), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_philza-{width}x{height}.jpg', 'tag_ids': ['ba2c968b-867a-49ce-aebc-3d978a204f4a', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.220201{'id': '34744761920', 'user_id': '14371185', 'user_name': 'Northernlion', 'game_id': '498380', 'community_ids': [], 'type': 'live', 'title': 'The Northernlion Live Super Show! (Rock of Ages 2 / Golf It / Hand Simulator)', 'viewer_count': 4118, 'started_at': datetime.datetime(2019, 7, 1, 22, 0, 35), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_northernlion-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
# 2019-07-01T15:35:44.223661{'id': '34743616832', 'user_id': '101725379', 'user_name': 'LazarBeamTwitch', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': 'playing minecraft with pewdiepie and james charles', 'viewer_count': 3723, 'started_at': datetime.datetime(2019, 7, 1, 20, 13, 58), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_lazarbeamtwitch-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.224174{'id': '34743314272', 'user_id': '23528098', 'user_name': 'AvoidingThePuddle', 'game_id': '509482', 'community_ids': [], 'type': 'live', 'title': 'Judge Eyes - Buy a shirt will ya? teespring.com/stores/ATP', 'viewer_count': 3922, 'started_at': datetime.datetime(2019, 7, 1, 19, 48, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_avoidingthepuddle-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.224181{'id': '34741951744', 'user_id': '43131877', 'user_name': 'Savjz', 'game_id': '512693', 'community_ids': [], 'type': 'live', 'title': '[Big Boss] Savjz fun builds', 'viewer_count': 3996, 'started_at': datetime.datetime(2019, 7, 1, 17, 57, 57), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_savjz-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
#
# 2019-07-01T15:35:44.227182{'id': '34741325712', 'user_id': '82197170', 'user_name': 'EWROON', 'game_id': '32982', 'community_ids': ['5181e78f-2280-42a6-873d-758e25a7c313'], 'type': 'live', 'title': '<EWRON> UDAWANE ŻYCIE! -> KOD EWRON W SKLEPIE FORTNITE! <- !ig !fb', 'viewer_count': 4293, 'started_at': datetime.datetime(2019, 7, 1, 17, 1, 42), 'language': 'pl', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_ewroon-{width}x{height}.jpg', 'tag_ids': ['f9d04efa-6e25-49bf-bf0a-da3e2addaf1b']}
#
#
#
# 2019-07-01T15:35:44.230060{'id': '34743187888', 'user_id': '16146075', 'user_name': 'Grimnax', 'game_id': '32982', 'community_ids': ['fd0eab99-832a-4d7e-8cc0-04d73deb2e54'], 'type': 'live', 'title': 'tek kişilik dev Gang | voRP | !yemeksepeti !prime !funny !güncelleme | insta: grimnax', 'viewer_count': 3807, 'started_at': datetime.datetime(2019, 7, 1, 19, 38, 4), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_grimnax-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
# 2019-07-01T15:35:44.230750{'id': '34743052320', 'user_id': '40754777', 'user_name': 'masondota2', 'game_id': '29595', 'community_ids': [], 'type': 'live', 'title': ' RANK 1', 'viewer_count': 3988, 'started_at': datetime.datetime(2019, 7, 1, 19, 26, 44), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_masondota2-{width}x{height}.jpg', 'tag_ids': ['3dc8f084-d886-4264-b20f-8bd5f90562b5', '60b8f13e-7022-481a-afff-07de3db129cc', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:35:44.232680{'id': '34743563632', 'user_id': '37522866', 'user_name': 'cyr', 'game_id': '32982', 'community_ids': ['ab18bbee-75ed-409d-aba9-8d4e3e2e541a', 'fd0eab99-832a-4d7e-8cc0-04d73deb2e54', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': "Uchiha Jones , he's not cute, he's tough", 'viewer_count': 3650, 'started_at': datetime.datetime(2019, 7, 1, 20, 9, 23), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cyr-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
# 2019-07-01T15:35:44.236519{'id': '34741209840', 'user_id': '114476906', 'user_name': 'KabajiOW', 'game_id': '488552', 'community_ids': ['8ea1e94f-4015-4f38-bd7e-745d8f42539a'], 'type': 'live', 'title': 'HIGH RANKED GAMES BOIS', 'viewer_count': 4050, 'started_at': datetime.datetime(2019, 7, 1, 16, 51, 18), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kabajiow-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '99e3f06a-a2b9-4963-bd2f-45283d644bc6']}
# 2019-07-01T15:35:44.237174{'id': '34744467152', 'user_id': '59308271', 'user_name': 'TFBlade', 'game_id': '21779', 'community_ids': [], 'type': 'live', 'title': 'NEW EMOTES SOON', 'viewer_count': 3675, 'started_at': datetime.datetime(2019, 7, 1, 21, 31, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tfblade-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
# 2019-07-01T15:35:44.240641{'id': '34740854112', 'user_id': '174955366', 'user_name': 'Solary', 'game_id': '513143', 'community_ids': [], 'type': 'live', 'title': 'Narkuss hard train twitch rival TOURNOI VIEUWEUR', 'viewer_count': 3669, 'started_at': datetime.datetime(2019, 7, 1, 16, 15, 42), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solary-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:35:44.240820{'id': '34742796240', 'user_id': '155601320', 'user_name': 'JLTomy', 'game_id': '32982', 'community_ids': ['4481e651-74ba-47f4-8374-9f94ec793d2a', '9133c470-6db4-4e16-a5d0-690e8a005bea'], 'type': 'live', 'title': 'JL TOMA - Yanis Abdouben de retour sur FlashLand ! (twitter : @PrismTomy) !video !rt !hrp', 'viewer_count': 3538, 'started_at': datetime.datetime(2019, 7, 1, 19, 5, 36), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_jltomy-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:35:44.241209{'id': '34743525712', 'user_id': '84432477', 'user_name': 'SwaggerSouls', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': "Minecraft Mondays but I'm geeking on GamerSupps", 'viewer_count': 3597, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 5), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_swaggersouls-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.245662{'id': '34744066928', 'user_id': '129112562', 'user_name': 'AlexRamiGaming', 'game_id': '33214', 'community_ids': [], 'type': 'live', 'title': 'Custom Games with Viewers!', 'viewer_count': 3101, 'started_at': datetime.datetime(2019, 7, 1, 20, 54, 26), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_alexramigaming-{width}x{height}.jpg', 'tag_ids': ['ff56eeeb-99ed-4a60-93fc-0b3f05d8661e', 'ac763b17-7bea-4632-9eb4-d106689ff409', '8486f56b-8677-44f7-8004-000295391524', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:35:44.257649{'id': '34742536080', 'user_id': '20992865', 'user_name': 'FollowGrubby', 'game_id': '12924', 'community_ids': ['848d95be-90b3-44a5-b143-6e373754c382', 'eb998ad4-8f95-4664-8ad4-08ca956a2e32', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': 'Mundead Monday - playing BEST race - !prime !buildorders !discord', 'viewer_count': 3158, 'started_at': datetime.datetime(2019, 7, 1, 18, 45, 12), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_followgrubby-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:35:44.276827{'id': '34742045184', 'user_id': '137347549', 'user_name': 'Locklear', 'game_id': '494925', 'community_ids': ['7f4e3996-78e8-46f6-bed0-586075cdd8ba'], 'type': 'live', 'title': 'UN HOMME ET UNE FEMME SUR UN RADEAU !Extension', 'viewer_count': 2884, 'started_at': datetime.datetime(2019, 7, 1, 18, 4, 34), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_locklear-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
#
# 2019-07-01T15:35:44.287293{'id': '34742098928', 'user_id': '24991333', 'user_name': 'imaqtpie', 'game_id': '29307', 'community_ids': [], 'type': 'live', 'title': 'spin good', 'viewer_count': 3135, 'started_at': datetime.datetime(2019, 7, 1, 18, 8, 47), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_imaqtpie-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:35:44.287291{'id': '34744541024', 'user_id': '90888563', 'user_name': 'h3x_TV', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': 'Vahşit | !yemeksepeti', 'viewer_count': 3011, 'started_at': datetime.datetime(2019, 7, 1, 21, 38, 54), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_h3x_tv-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
#
#
# 2019-07-01T15:35:44.293338{'id': '34743337552', 'user_id': '112837021', 'user_name': 'UMGEvents', 'game_id': '27471', 'community_ids': ['4203fe60-1a97-441a-9e5b-9952a31e22b0', '558ffafb-6f75-44ff-8cb7-a4f045d2399f', 'e460229e-2100-4c42-894c-d758651f06c6'], 'type': 'live', 'title': 'Minecraft Monday Week 2', 'viewer_count': 2790, 'started_at': datetime.datetime(2019, 7, 1, 19, 50, 52), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_umgevents-{width}x{height}.jpg', 'tag_ids': ['b13ce7d5-d513-49ff-a957-76f193df42aa', '1eba3cfe-51cc-460a-8259-bc8bb987f904', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:35:44.313992{'id': '34741263712', 'user_id': '101286926', 'user_name': 'WPMEzony', 'game_id': '27471', 'community_ids': ['630b0566-cee6-42e4-84ad-a18532d7f56b', 'c8f59921-b10b-49ab-99ac-0a8dc49df36d'], 'type': 'live', 'title': 'GALAKTYCZNY MOD O 20 !mody2 !jak 🍯KOD:HONEY🍯😡18+😡', 'viewer_count': 2480, 'started_at': datetime.datetime(2019, 7, 1, 16, 56, 31), 'language': 'pl', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_wpmezony-{width}x{height}.jpg', 'tag_ids': ['f1e3759c-35b3-4858-a50f-8f9cafc2660f', '2b2a4874-8a3c-4995-b9e2-2a0bce1eb536', 'e90b5f6e-4c6e-4003-885b-4d0d5adeb580', '8282259b-a997-4c63-b908-24027f64ac9a', 'fd8f5e68-42d3-4544-a273-5fc92dabc568', 'f9d04efa-6e25-49bf-bf0a-da3e2addaf1b']}
#
# 2019-07-01T15:35:44.326252{'id': '34740706752', 'user_id': '22552479', 'user_name': 'Giantwaffle', 'game_id': '495764', 'community_ids': ['23653182-871f-44d5-990c-68fc600abcf0', '5181e78f-2280-42a6-873d-758e25a7c313', 'fd0eab99-832a-4d7e-8cc0-04d73deb2e54'], 'type': 'live', 'title': 'Last Stream Before Vacation | !charm for R6 Charm', 'viewer_count': 2605, 'started_at': datetime.datetime(2019, 7, 1, 16, 0, 57), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_giantwaffle-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:36:44.316629{'id': '34743486944', 'user_id': '11001241', 'user_name': 'KYR_SP33DY', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': '#MinecraftMonday Hunger Games starts at 1PM PDT/4pm EDT', 'viewer_count': 4189, 'started_at': datetime.datetime(2019, 7, 1, 20, 2, 53), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kyr_sp33dy-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.316907{'id': '34744467152', 'user_id': '59308271', 'user_name': 'TFBlade', 'game_id': '21779', 'community_ids': [], 'type': 'live', 'title': 'NEW EMOTES SOON', 'viewer_count': 3640, 'started_at': datetime.datetime(2019, 7, 1, 21, 31, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tfblade-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.318431{'id': '34743525712', 'user_id': '84432477', 'user_name': 'SwaggerSouls', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': "Minecraft Mondays but I'm geeking on GamerSupps", 'viewer_count': 3613, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 5), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_swaggersouls-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.318423{'id': '34743894176', 'user_id': '193054811', 'user_name': 'MarcaoRX', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': '18+ [UP-RP] MARCÃO DEUS? FÉ  --> !ofertas  !sociais', 'viewer_count': 4146, 'started_at': datetime.datetime(2019, 7, 1, 20, 38, 23), 'language': 'pt', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_marcaorx-{width}x{height}.jpg', 'tag_ids': ['39ee8140-901a-4762-bfca-8260dea1310f']}
# 2019-07-01T15:36:44.318595{'id': '34743531232', 'user_id': '123922797', 'user_name': 'IamCristinini', 'game_id': '32982', 'community_ids': ['14778f2b-de66-48d7-ae0b-8187250de029', '831ccb45-e159-4873-a61b-74693bdc5756', 'ad14d4fc-1a7c-413f-aa32-4906ef3669ae'], 'type': 'live', 'title': '🔴 [DespistaosRp] 👮\u200d♀️ POLICIA - Cadete Irina Wallace - LSPD [+18] | Follow @IamCristinini', 'viewer_count': 3981, 'started_at': datetime.datetime(2019, 7, 1, 20, 6, 34), 'language': 'es', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_iamcristinini-{width}x{height}.jpg', 'tag_ids': ['d4bb9c58-2141-4881-bcdc-3fe0505457d1']}
# 2019-07-01T15:36:44.319856{'id': '34743563632', 'user_id': '37522866', 'user_name': 'cyr', 'game_id': '32982', 'community_ids': ['ab18bbee-75ed-409d-aba9-8d4e3e2e541a', 'fd0eab99-832a-4d7e-8cc0-04d73deb2e54', 'ff1e77af-551d-4993-945c-f8ceaa2a2829'], 'type': 'live', 'title': "Uchiha Jones , he's not cute, he's tough", 'viewer_count': 3644, 'started_at': datetime.datetime(2019, 7, 1, 20, 9, 23), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cyr-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:36:44.324198{'id': '34744541024', 'user_id': '90888563', 'user_name': 'h3x_TV', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': 'Vahşit | !yemeksepeti', 'viewer_count': 3200, 'started_at': datetime.datetime(2019, 7, 1, 21, 38, 54), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_h3x_tv-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
# 2019-07-01T15:36:44.323874{'id': '34744066928', 'user_id': '129112562', 'user_name': 'AlexRamiGaming', 'game_id': '33214', 'community_ids': [], 'type': 'live', 'title': 'Custom Games with Viewers!', 'viewer_count': 2962, 'started_at': datetime.datetime(2019, 7, 1, 20, 54, 26), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_alexramigaming-{width}x{height}.jpg', 'tag_ids': ['ff56eeeb-99ed-4a60-93fc-0b3f05d8661e', 'ac763b17-7bea-4632-9eb4-d106689ff409', '8486f56b-8677-44f7-8004-000295391524', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.325680{'id': '34743337552', 'user_id': '112837021', 'user_name': 'UMGEvents', 'game_id': '27471', 'community_ids': ['4203fe60-1a97-441a-9e5b-9952a31e22b0', '558ffafb-6f75-44ff-8cb7-a4f045d2399f', 'e460229e-2100-4c42-894c-d758651f06c6'], 'type': 'live', 'title': 'Minecraft Monday Week 2', 'viewer_count': 2833, 'started_at': datetime.datetime(2019, 7, 1, 19, 50, 52), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_umgevents-{width}x{height}.jpg', 'tag_ids': ['b13ce7d5-d513-49ff-a957-76f193df42aa', '1eba3cfe-51cc-460a-8259-bc8bb987f904', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.325483{'id': '34740854112', 'user_id': '174955366', 'user_name': 'Solary', 'game_id': '513143', 'community_ids': [], 'type': 'live', 'title': 'Narkuss hard train twitch rival TOURNOI VIEUWEUR', 'viewer_count': 3710, 'started_at': datetime.datetime(2019, 7, 1, 16, 15, 42), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solary-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:36:44.328773{'id': '34743616832', 'user_id': '101725379', 'user_name': 'LazarBeamTwitch', 'game_id': '27471', 'community_ids': [], 'type': 'live', 'title': 'playing minecraft with pewdiepie and james charles', 'viewer_count': 3724, 'started_at': datetime.datetime(2019, 7, 1, 20, 13, 58), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_lazarbeamtwitch-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:36:44.331170{'id': '34741951744', 'user_id': '43131877', 'user_name': 'Savjz', 'game_id': '512693', 'community_ids': [], 'type': 'live', 'title': '[Big Boss] Savjz fun builds', 'viewer_count': 3979, 'started_at': datetime.datetime(2019, 7, 1, 17, 57, 57), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_savjz-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
# 2019-07-01T15:36:44.332953{'id': '34744761920', 'user_id': '14371185', 'user_name': 'Northernlion', 'game_id': '498380', 'community_ids': [], 'type': 'live', 'title': 'The Northernlion Live Super Show! (Rock of Ages 2 / Golf It / Hand Simulator)', 'viewer_count': 4102, 'started_at': datetime.datetime(2019, 7, 1, 22, 0, 35), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_northernlion-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '2a14b52e-d459-4c92-be11-5d86b898f6b6']}
#
# 2019-07-01T15:36:44.333378{'id': '34743187888', 'user_id': '16146075', 'user_name': 'Grimnax', 'game_id': '32982', 'community_ids': ['fd0eab99-832a-4d7e-8cc0-04d73deb2e54'], 'type': 'live', 'title': 'tek kişilik dev Gang | voRP | !yemeksepeti !prime !funny !güncelleme | insta: grimnax', 'viewer_count': 3823, 'started_at': datetime.datetime(2019, 7, 1, 19, 38, 4), 'language': 'tr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_grimnax-{width}x{height}.jpg', 'tag_ids': ['f08d5873-f0c7-4912-94ba-a41933b4c141']}
# 2019-07-01T15:36:44.334411{'id': '34737937840', 'user_id': '198506129', 'user_name': 'SolaryFortnite', 'game_id': '32982', 'community_ids': [], 'type': 'live', 'title': "GTA LIFE | LE RETOUR D'ETHANOU", 'viewer_count': 4333, 'started_at': datetime.datetime(2019, 7, 1, 9, 23, 46), 'language': 'fr', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solaryfortnite-{width}x{height}.jpg', 'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648']}
# 2019-07-01T15:36:44.334034{'id': '34743052320', 'user_id': '40754777', 'user_name': 'masondota2', 'game_id': '29595', 'community_ids': [], 'type': 'live', 'title': ' RANK 1', 'viewer_count': 4025, 'started_at': datetime.datetime(2019, 7, 1, 19, 26, 44), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_masondota2-{width}x{height}.jpg', 'tag_ids': ['3dc8f084-d886-4264-b20f-8bd5f90562b5', '60b8f13e-7022-481a-afff-07de3db129cc', '6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
#
#
#
#
#
# 2019-07-01T15:36:44.341655{'id': '34743314272', 'user_id': '23528098', 'user_name': 'AvoidingThePuddle', 'game_id': '509482', 'community_ids': [], 'type': 'live', 'title': 'Judge Eyes - Buy a shirt will ya? teespring.com/stores/ATP', 'viewer_count': 3916, 'started_at': datetime.datetime(2019, 7, 1, 19, 48, 48), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_avoidingthepuddle-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039']}
# 2019-07-01T15:36:44.341589{'id': '34742126896', 'user_id': '25604128', 'user_name': 'guit88man', 'game_id': '115977', 'community_ids': ['d808cf0b-88c3-4ef2-acd0-bae82f17e9c3'], 'type': 'live', 'title': 'Ведьмак 3 - день 2', 'viewer_count': 4030, 'started_at': datetime.datetime(2019, 7, 1, 18, 11, 2), 'language': 'ru', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_guit88man-{width}x{height}.jpg', 'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327']}
# 2019-07-01T15:36:44.341450{'id': '34741209840', 'user_id': '114476906', 'user_name': 'KabajiOW', 'game_id': '488552', 'community_ids': ['8ea1e94f-4015-4f38-bd7e-745d8f42539a'], 'type': 'live', 'title': 'HIGH RANKED GAMES BOIS', 'viewer_count': 4105, 'started_at': datetime.datetime(2019, 7, 1, 16, 51, 18), 'language': 'en', 'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kabajiow-{width}x{height}.jpg', 'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039', '99e3f06a-a2b9-4963-bd2f-45283d644bc6']}
# ...
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 28, in twitch_chat_metadata_scraper
#     streams_iterator = client.get_streams(user_logins=channel_name)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 28, in twitch_chat_metadata_scraper
#     streams_iterator = client.get_streams(user_logins=channel_name)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 28, in twitch_chat_metadata_scraper
#     streams_iterator = client.get_streams(user_logins=channel_name)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-18f01f1519fc>", line 44, in twitch_chat_metadata_scraper
#     time.sleep(60.0 - ((time.time() - starttime) % 60.0))
#   File "<ipython-input-2-18f01f1519fc>", line 28, in twitch_chat_metadata_scraper
#     streams_iterator = client.get_streams(user_logins=channel_name)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/api.py", line 54, in get_streams
#     params=params
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 77, in __init__
#     self.next_page()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 104, in next_page
#     response = self._request_get(self._path, params=self._params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 57, in _request_get
#     return self._request_get(path, params=params)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   [Previous line repeated 2 more times]
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   [Previous line repeated 2 more times]
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 42, in _request_get
#     self._wait_for_rate_limit_reset()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
#   File "/Users/michaellin/anaconda3/lib/python3.7/site-packages/twitch/helix/base.py", line 26, in _wait_for_rate_limit_reset
#     time.sleep(wait_time)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-18f01f1519fc> in <module>
#      50     processes = my_list
#      51     pool = Pool(processes=len(my_list))
# ---> 52     pool.map(twitch_chat_metadata_scraper, processes)
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     288         in a list that is returned.
#     289         '''
# --> 290         return self._map_async(func, iterable, mapstar, chunksize).get()
#     291
#     292     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     675
#     676     def get(self, timeout=None):
# --> 677         self.wait(timeout)
#     678         if not self.ready():
#     679             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     672
#     673     def wait(self, timeout=None):
# --> 674         self._event.wait(timeout)
#     675
#     676     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
my_list = top_50_channel_list[:20] + ['edisonparklive'] + ['singsing']

# %%
len(my_list)
# Out:
# 22

# %%
my_list
